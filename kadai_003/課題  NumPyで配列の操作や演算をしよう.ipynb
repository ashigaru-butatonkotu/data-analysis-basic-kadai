# %%
import numpy as np

# %%
A = np.array([[0,1],[2,3],[4,5]])
B = np.array([[0,1,2,3],[4,5,6,7]])

# %%
np.dot(A,B)
# Out:
# array([[ 4,  5,  6,  7],
#        [12, 17, 22, 27],
#        [20, 29, 38, 47]])

# %%
matrix_result = np.dot(A, B)
print(result)
# Out:
# [[ 4  5  6  7]
#  [12 17 22 27]
#  [20 29 38 47]]

# %%
print(matrix_result.max())
# Out:
# 47
